# %% [markdown]
# ## Hands-on
# ### Quantifying and Reducing Gender Stereotypes in Portuguese Word Embeddings
#
# Based in the following paper: Man is to Computer Programmer as Woman is to Homemaker? Debiasing Word Embeddings by Tolga Bolukbasi, Kai-Wei Chang, James Zou, Venkatesh Saligrama, and Adam Kalai. Proceedings of NIPS 2016.

# %%
from __future__ import print_function, division
# %matplotlib inline
from matplotlib import pyplot as plt
import json
import random
import numpy as np

import debiaswe as dwe
import debiaswe.we as we
from debiaswe.we import WordEmbedding
from debiaswe.data import load_professions_pt
#from debiaswe.debias import debias

# %% [markdown]
# ### Gender Bias in Word Embedding
#
#
# - #### Step 1: Load data

# %%
# load google news word2vec
E = WordEmbedding('./embeddings/cbow3_s300.txt')
# load professions
#professions = load_professions_pt()
#profession_words = [p[0] for p in professions]
# Out:
# *** Reading data from ./embeddings/cbow3_s300.txt
# (24982, 300)
# 24982 words of dimension 300 : ., a, o, e, ..., decolar, discursou, sinai, ldu
# 24982 words of dimension 300 : ., a, o, e, ..., decolar, discursou, sinai, ldu

# %% [markdown]
# - #### Step 2: Define Gender Direction

# %%
# gender direction
v_gender = E.diff('ela', 'ele')

# %% [markdown]
# - #### Step 3:Generating analogies of "Homem: x :: Mulher : y"

# %%
a_gender = E.best_analogies_dist_thresh(v_gender)

for (a,b,c) in a_gender:
    print(a+"-"+b)
# Out:
# Computing neighbors
# Mean: 12.236890561204067
# Median: 5.0
# ela-ele
# dela-dele
# encantadora-magnífica
# sozinha-sozinho
# vê-la-vê-lo
# assassinada-assassinado
# namorado-companheiro
# candidata-candidato
# doida-louco
# ternura-crueldade
# noivo-amigo
# nascida-nascido
# bêbada-cansado
# irritada-entusiasmado
# presa-preso
# sentada-sentado
# orgulhosa-orgulhoso
# aposentada-delegada
# natália-macário
# morta-morto
# lenço-colete
# jenny-doug
# casado-confrontado
# filhos-discípulos
# confusa-optimista
# bebé-homem
# condenada-condenado
# lídia-artur
# eleita-eleito
# assustada-empolgado
# afeto-empenho
# sensual-extravagante
# adorável-estúpido
# mulher-ex-mulher
# casal-agricultor
# marido-filho
# feto-indivíduo
# ciúme-patriotismo
# ingenuidade-insistência
# grávida-desempregado
# casada-laureado
# interpretada-auxiliado
# protagonista-herói
# maridos-camaradas
# preenche-cumpre
# atores-jogadores
# protagonizada-liderada
# autora-autor
# fundadora-fundador
# colombiana-paraguaia
# cineastas-arqueólogos
# ex-marido-sucessor
# casar-juntar
# cama-cabeça
# feminista-anarquista
# escritora-romancista
# natureza-existência
# gentil-corajoso
# semente-plantação
# diretora-gerente
# vertentes-frentes
# ansiosa-ansioso
# refém-prisioneiro
# menina-advogada
# foge-escapou
# pele-nuca
# carmen-narciso
# doçura-persistência
# palestinos-rebeldes
# subjacentes-inerentes
# enterrada-enterrado
# convencida-convicto
# caminhando-avançando
# rebecca-brian
# expulsa-expulso
# directora-director
# apelidada-apelidado
# tímida-agressiva
# bonita-esperto
# casou-uniu
# capturada-capturado
# relaxa-mcgee
# susan-andrew
# seduzir-convencer
# esperta-exigente
# quieta-quieto
# afeição-gratidão
# moradora-morador
# júlia-lídia
# imagem-reputação
# afirma-adiantando
# conheceu-substituiu
# amigas-senhoras
# fruta-cana-de-açúcar
# surpreendida-surpreendido
# cuidando-ciente
# apartamento-acampamento
# bandidos-vândalos
# bem-vinda-bem-vindo
# considerada-considerado
# observou-admitiu
# atraente-agressivo
# apaixonada-dominada
# filhas-faces
# gerado-motivado
# ferida-ferido
# ajudá-la-ajudá-lo
# dizendo-admitindo
# amante-irmão
# preocupada-acostumado
# peitos-inimigos
# garoto-jogador
# tiveram-terão
# blusa-jaqueta
# furiosa-furioso
# interfaces-ferramentas
# contratada-contratado
# cineasta-sociólogo
# bebê-garoto
# judia-judaica
# doces-pratos
# maravilhosa-ótima
# irmã-sucessora
# interrupção-suspensão
# teve-terá
# protagonistas-atacantes
# herdeira-herdeiro
# esquece-esqueçam
# pianista-guitarrista
# consorte-regente
# deusa-mitologia
# separou-dispôs
# tê-la-tê-lo
# noivos-sequestradores
# internada-hospitalizado
# gary-steve
# amava-admiro
# constatado-admitido
# mudou-se-deslocou-se
# cantora-banda
# concluída-cumprida
# netos-companheiros
# acompanhada-seguido
# pênis-bastão
# apoiadores-generais
# violeta-púrpura
# apaixona-desloca
# amor-sacrifício
# coelho-sampaio
# naturalmente-ironicamente
# ex-secretário-secretário
# selecionada-convocado
# esposo-servo
# dançar-tocar
# cantou-tocou
# rosto-queixo
# finalizado-testado
# espaçonave-nasa
# convidada-convidado
# retratada-contada
# mocinha-srta
# filhotes-ninhos
# vestes-fichas
# aaron-craig
# pijama-traje
# stephanie-vince
# começam-passariam
# coordenados-conduzidos
# engraçada-perigosa
# lobisomem-marinheiro
# perseguições-atrocidades
# condessa-duque
# anões-guerreiros
# acabamos-temos
# claustro-templo
# foliões-taxistas
# ex-líder-dirigente
# vã£o-tãªm
# diz-adiantou
# estilista-empresário
# terezinha-fe
# heather-jake
# saído-regressado
# criatura-caverna
# possamos-tenhamos
# estrelada-lideradas
# notou-exigia
# cobria-cobrem
# chama-chamou
# querida-ok
# namorando-entendendo
# eclosão-chegada
# casou-se-encontrou-se
# escolheu-utilizou
# videoclipe-disco
# dever-se-deveu-se
# pcp-autarca
# flu-cruzeiro
# mercedes-mclaren
# dividido-divide-se
# vibração-dureza
# eyes-love
# sexualidade-homossexualidade
# chuveiro-fogão
# comprometidos-dispostos
# pálida-escura
# samantha-bud
# observando-ignorando
# simpática-modesta
# sorriso-gesto
# pede-ordenou
# transferida-remetido
# povoação-cidadela
# interrompeu-suspendeu
# sugestão-nomeação
# demônio-inimigo
# incentiva-facilitou
# ponderou-assegurou
# célula-membrana
# beijando-segurando
# penúltimo-último
# feliz-grato
# impacto-avanço
# começa-continuando
# envolvida-implicado
# selecionadas-utilizadas
# linda-estúpida
# delicadeza-bravura
# monarca-governante
# mãe-inocência
# islandês-sueco
# faz-fazem
# crias-águias
# jerusalém-constantinopla
# estrelou-atuou
# joana-filomena
# delicada-preocupante
# vice-liderança-titularidade
# pombos-elefantes
# doação-devolução
# iémen-egipto
# simpatia-confiança
# perguntava-pergunto
# albanês-búlgaro
# atendente-garçom
# discutindo-avaliando
# viver-jogar
# pomba-luva
# tava-estou
# tenta-tentará
# lorena-saboia
# poderosa-poderoso
# boavista-salgueiros
# eslováquia-bulgária
# cantoras-equipas
# acusada-acusado
# prejudicado-punido
# garota-celebridade
# protagonizar-liderar
# recorda-recordou
# jovens-aprendizes
# atacada-atacado
# identificada-identificado
# realizam-incluíam
# olhou-partiu
# suécia-alemanha
# acertado-negociado
# descobre-ordena
# creche-farmácia
# herança-hegemonia
# cheryl-porter
# apaixonou-interessou
# imigrante-diplomata
# saí-fui
# havaí-egito
# consegue-precisará
# feminismo-liberalismo
# casaram-transformaram
# honesta-honesto
# substituída-liderado
# vogue-revista
# educada-educado
# cantores-guitarristas
# acompanhou-liderou
# amar-perdoar
# chamava-chamam
# nomeada-nomeado
# intimidade-memória
# dotado-dispondo
# detida-controlada
# explica-confirma
# transformações-inovações
# muda-mudaria
# finalidades-opções
# bailarinos-futebolistas
# telhado-pavimento
# fala-falavam
# fechado-desativado
# exclamou-respondeu
# convivência-coexistência
# lemos-brito
# canta-tocava
# digestão-remoção
# pressões-resistências
# empresários-especialistas
# melodia-partitura
# brigando-lutando
# adolescente-rapaz
# guarda-roupa-reportório
# finge-precisa
# desaparecimento-assassínio
# cantada-inventada
# estória-historia
# riso-grito
# cantando-tocando
# diocese-arquidiocese
# sintonia-contraste
# divertida-fantástica
# balanços-cálculos
# componente-elemento
# doados-enviados
# tratada-aproveitada
# richard-edwin
# reggae-jazz
# extremistas-combatentes
# apresentadora-apresentador
# ex-namorado-compatriota
# pensa-crê
# amável-discreto
# calçada-contramão
# saíam-chegavam
# subvenções-facilidades
# torna-se-tornando-o
# apareceu-apostou
# moça-multidão
# rejeitada-aceito
# menino-ladrão
# revitalização-demolição
# noticiosa-lusa
# algum-nenhum
# ergueu-erguer
# útero-estômago
# pensão-indemnização
# vagina-barriga
# clareza-rigor
# sensata-concreta
# culpada-culpado
# devotos-crentes
# ficaremos-estaremos
# nela-ali
# padrinho-mentor
# excitação-inércia
# moram-pensem
# casamento-encontro
# velório-evento
# apresentou-rejeitou
# freqüentemente-comumente
# cantar-escrever
# conhecê-la-conhecê-lo
# encaminhada-encaminhado
# desejos-compatriotas
# decoração-confecção
# comédia-faroeste
# determinante-decisiva
# desintegração-expulsão
# hong-berlusconi
# retirou-se-retornou
# tentei-tento
# chateada-tonto
# portugueses-holandeses
# engravidar-matá-lo
# venezuelana-catalã
# katie-larry
# cenas-réplicas
# transar-pegá-lo
# casei-importo
# ama-mataria
# traiu-atacou
# fenômeno-fenómeno
# produzida-fabricado
# suriname-panamá
# presos-acusados
# comenta-declarou
# recheio-cardápio
# emocionalmente-psicologicamente
# casar-se-competir
# violinista-arqueólogo
# intensos-rápidos
# literatura-historiografia
# alunos-investigadores
# virgínia-pensilvânia
# acompanhava-acompanharam
# perseguidos-punidos
# elétrons-átomos
# nasce-surgia
# pensadores-historiadores
# briga-luta
# vimos-tínhamos
# sobrinha-mã£e
# cevada-feijão
# fundir-converter
# ficara-encontrava-se
# promovem-requerem
# detetive-investigador
# beija-beijou
# cápsula-nave
# torta-frango
# decide-decida
# maluf-autuori
# alverca-faro
# constatou-confirmam
# atraído-pressionado
# propósitos-esquemas
# surfe-boxe
# plantel-treinador
# quartel-general-comandante
# desce-subia
# apresenta-incluirá
# vinhas-pastagens
# beijou-devolve
# professora-estudante
# evidente-provável
# frisa-sublinhando
# paris-lyon
# padrinhos-sucessores
# ótimos-excelentes
# ressalta-ressaltando
# atrações-novidades
# beatriz-marcela
# melancolia-cólera
# artistas-autores
# atriz-jogadora
# adorava-preferia
# cabeleireiro-cozinheiro
# chácara-fazenda
# baiana-pernambucana
# vejam-ouçam
# poderemos-teremos
# estatuto-diploma
# pensava-pensavam
# contribuir-servir
# ilustrada-ilustrado
# gostosa-gostoso
# trabalhado-treinado
# nm-mhz
# cielo-sampras
# finalidade-propósito
# rejeição-destituição
# contou-contaram
# catálogo-dicionário
# satisfazer-cumprir
# elétron-átomo
# prostituta-farsa
# participam-participarão
# aposentadoria-demissão
# nepal-mali
# próprio-prã³prio
# aproximar-qualificar
# representantes-administradores
# tensa-complicada
# eslovaca-helénica
# lamenta-lamentamos
# dorival-tite
# interação-correlação
# espetáculo-folhetim
# triste-frustrante
# olhos-portões
# pescoço-punho
# cooperar-avançar
# albaneses-armênios
# classificada-classificado
# precioso-valioso
# planície-trácia
# padrasto-patrão
# compensações-provisões
# lâmina-espada
# tema-tópico
# assustadora-impressionante
# fotografar-projetar
# destaques-artilheiros
# zumbis-robôs
# ocorrer-haver
# índole-cariz
# erudito-estudioso
# confessa-afirmava
# denominação-designação
# realidades-fórmulas
# desperta-despertou
# estético-filosófico
# favela-upp
# diálogo-embate
# sair-retornar
# aposentos-quartéis
# filhote-macaco
# pedagogia-astronomia
# correia-fernandes
# impedidos-obrigados
# perdi-tenho
# brincar-aprender
# ocorra-implique

# %% [markdown]
# - #### Step 4: Analyzing gender bias in word vectors asscoiated with professions

# %%
# profession analysis gender
sp = sorted([(E.v(w).dot(v_gender), w) for w in profession_words])

sp[0:20], sp[-20:]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-3ed95b8950ad> in <module>()
#       1 # profession analysis gender
# ----> 2 sp = sorted([(E.v(w).dot(v_gender), w) for w in profession_words])
#       3
#       4 sp[0:20], sp[-20:]
#
# NameError: name 'profession_words' is not defined

# %% [markdown]
# - #### Step 5:

# %%
#debias(E, gender_specific_words, defs, equalize_pairs)
